# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
root_dir  = '/content/drive/MyDrive/Weed_Detection'

# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.7/898.7 kB 15.3 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import os
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO('yolov8n.pt')
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 188MB/s]

# %%
result = model.train(data = os.path.join(root_dir,'Weed.yaml'),epochs = 20)
# Out:
# Ultralytics 8.3.49 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
# !cp /content/runs/detect /content/drive/MyDrive/Weed_Detection
# Out:
# cp: -r not specified; omitting directory '/content/runs/detect'

# %%
# !cp /content/runs/detect/train2/weights/best.pt /content/drive/MyDrive/Weed_Detection

# %%
from ultralytics import YOLO
import cv2

# Load the trained model
model_path = '/content/drive/MyDrive/Weed_Detection/best1.pt' # Update with your model path
model = YOLO(model_path)

# Path to the new image
image_path = '/content/drive/MyDrive/Weed_Detection/data/val/images/agri_0_3720.jpeg' # Update with your image path

# Perform inference
results = model(image_path)

# Visualize the results (optional)
for r in results:
    im_array = r.plot()  # plot a BGR numpy array of predictions
    cv2.imwrite('result_image.jpg', im_array) # save the image

# Display or process the results further
results
# Out:
# image 1/1 /content/drive/MyDrive/Weed_Detection/data/val/images/agri_0_3720.jpeg: 640x640 29 crops, 242.5ms
# Speed: 5.7ms preprocess, 242.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'crop', 1: 'weed'}
#  obb: None
#  orig_img: array([[[ 49,  52,  56],
#          [ 39,  42,  46],
#          [ 32,  35,  39],
#          ...,
#          [152, 175, 197],
#          [155, 178, 200],
#          [153, 176, 198]],
#
#         [[ 92,  95,  99],
#          [ 84,  87,  91],
#          [ 74,  77,  81],
#          ...,
#          [155, 178, 200],
#          [156, 179, 201],
#          [155, 178, 200]],
#
#         [[110, 113, 117],
#          [108, 111, 115],
#          [112, 115, 119],
#          ...,
#          [155, 176, 197],
#          [155, 178, 200],
#          [156, 179, 201]],
#
#         ...,
#
# ...

# %%
from IPython.display import Image
Image('result_image.jpg')
